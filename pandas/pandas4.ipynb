# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[(df['sex']=='Male') & (df['day']=='Fri') & (df['size']==2)]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 90        28.97  3.00  Male    Yes  Fri  Dinner     2             14.48
# 91        22.49  3.50  Male     No  Fri  Dinner     2             11.24
# 96        27.28  4.00  Male    Yes  Fri  Dinner     2             13.64
# 97        12.03  1.50  Male    Yes  Fri  Dinner     2              6.02
# 98        21.01  3.00  Male    Yes  Fri  Dinner     2             10.50
# 99        12.46  1.50  Male     No  Fri  Dinner     2              6.23
# 220       12.16  2.20  Male    Yes  Fri   Lunch     2              6.08
# 224       13.42  1.58  Male    Yes  Fri   Lunch     2              6.71
#
#             Payer Name         CC Number Payment ID
# 90        Daniel Mason  3597456900644078    Fri4175
# 91           Earl Horn  6011849326227398    Fri5700
# 96         Eric Carter  4563054452787961    Fri3159
# 97        Eric Herrera      580116092652    Fri9268
# 98          Michael Li  4831801127457917     Fri144
# ...

# %%
option = ['Sat','Sun','Thur']
df[df['day'].isin(option)]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(12345676543)
# Out:
# '6543'

# %%
df['last four'] = df['CC Number'].apply(last_four)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last four
# ...

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
def dollar(price):
    if price<10:
        return '$'
    elif price<20:
        return '$$'
    else:
        return '$$$'

# %%
df['yel'] = df['total_bill'].apply(dollar)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last four  yel
# ...

# %%
def quality(total_bill,tip):
    if tip/total_bill>0.15:
        return 'Generous'
    else:
        return 'other'

# %%
quality(16,4)
# Out:
# 'Generous'

# %%
# slow method

# %%
df['tip_info'] = df[ ['total_bill','tip'] ].apply( lambda df : quality( df['total_bill'], df['tip']),axis = 1 )

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
#fast method atleast 10 times

# %%
df['tip_info'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID last four  yel  tip_info
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$     other
# ...

# %%
df = pd.read_csv("tips.csv")

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df[df['tip'] == 10.0]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
#
#         Payer Name         CC Number Payment ID
# 170  Gregory Clark  5473850968388236    Sat1954

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['sex']= df['sex'].replace(['Female','Male'],['F','M'])

# %%
df
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 2         21.01  3.50   M     No   Sun  Dinner     3              7.00
# 3         23.68  3.31   M     No   Sun  Dinner     2             11.84
# 4         24.59  3.61   F     No   Sun  Dinner     4              6.15
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 239       29.03  5.92   M     No   Sat  Dinner     3              9.68
# 240       27.18  2.00   F    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00   M    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
mymap = {'F' : 'Female','M' : 'Male'}

# %%
df['sex'].map(mymap)
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
simple_df = pd.DataFrame([1,2,2,2],['a','b','c','d'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
# C:\Users\kanis\AppData\Local\Temp\ipykernel_28548\1152120679.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)]
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 8         15.04  1.96   M     No   Sun  Dinner     2              7.52
# 9         14.78  3.23   M     No   Sun  Dinner     2              7.39
# 10        10.27  1.71   M     No   Sun  Dinner     2              5.14
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 234       15.53  3.00   M    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 236       12.60  1.00   M    Yes   Sat  Dinner     2              6.30
# ...

# %%
df.nlargest(10,'total_bill')
# Out:
#      total_bill    tip sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00   M    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00   M     No   Sat  Dinner     4             12.08
# 59        48.27   6.73   M     No   Sat  Dinner     4             12.07
# 156       48.17   5.00   M     No   Sun  Dinner     6              8.03
# 182       45.35   3.50   M    Yes   Sun  Dinner     3             15.12
# 102       44.30   2.50   F    Yes   Sat  Dinner     3             14.77
# 197       43.11   5.00   F    Yes  Thur   Lunch     4             10.78
# 142       41.19   5.00   M     No  Thur   Lunch     5              8.24
# 184       40.55   3.00   M    Yes   Sun  Dinner     2             20.27
# 95        40.17   4.73   M    Yes   Fri  Dinner     4             10.04
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# ...

# %%
df.sort_values('tip',ascending=False).iloc[:5]
# Out:
#      total_bill    tip sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00   M    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00   M     No   Sat  Dinner     4             12.08
# 23        39.42   7.58   M     No   Sat  Dinner     4              9.86
# 59        48.27   6.73   M     No   Sat  Dinner     4             12.07
# 141       34.30   6.70   M     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.sample(5)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 48        28.55  2.05   M     No   Sun  Dinner     3              9.52
# 165       24.52  3.48   M     No   Sun  Dinner     3              8.17
# 128       11.38  2.00   F     No  Thur   Lunch     2              5.69
# 84        15.98  2.03   M     No  Thur   Lunch     2              7.99
# 5         25.29  4.71   M     No   Sun  Dinner     4              6.32
#
#             Payer Name         CC Number Payment ID
# 48       Austin Fisher  6011481668986587    Sun4142
# 165       Jacob Hansen     4031116007387    Sun9043
# 128  Christine Perkins  3548391118913991   Thur8551
# 84         Jason Jones  4442984204923315   Thur1944
# 5           Erik Smith   213140353657882    Sun9679

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 46        22.23  5.00   M     No   Sun  Dinner     2             11.12
# 115       17.31  3.50   F     No   Sun  Dinner     2              8.65
# 172        7.25  5.15   M    Yes   Sun  Dinner     2              3.62
# 136       10.33  2.00   F     No  Thur   Lunch     2              5.16
# 72        26.86  3.14   F    Yes   Sat  Dinner     2             13.43
# 129       22.82  2.18   M     No  Thur   Lunch     3              7.61
# 158       13.39  2.61   F     No   Sun  Dinner     2              6.70
# 76        17.92  3.08   M    Yes   Sat  Dinner     2              8.96
# 24        19.82  3.18   M     No   Sat  Dinner     2              9.91
# 239       29.03  5.92   M     No   Sat  Dinner     3              9.68
# 47        32.40  6.00   M     No   Sun  Dinner     4              8.10
# 131       20.27  2.83   F     No  Thur   Lunch     2             10.14
# ...
