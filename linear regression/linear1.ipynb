# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df['total'] = df['TV']+df['radio']+df['newspaper']

# %%
df
# Out:
#         TV  radio  newspaper  sales  total
# 0    230.1   37.8       69.2   22.1  337.1
# 1     44.5   39.3       45.1   10.4  128.9
# 2     17.2   45.9       69.3    9.3  132.4
# 3    151.5   41.3       58.5   18.5  251.3
# 4    180.8   10.8       58.4   12.9  250.0
# ..     ...    ...        ...    ...    ...
# 195   38.2    3.7       13.8    7.6   55.7
# 196   94.2    4.9        8.1    9.7  107.2
# 197  177.0    9.3        6.4   12.8  192.7
# 198  283.6   42.0       66.2   25.5  391.8
# 199  232.1    8.6        8.7   13.4  249.4
#
# [200 rows x 5 columns]

# %%
sns.scatterplot(data = df, x = 'total',y = 'sales')
# Out:
# <AxesSubplot:xlabel='total', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = 'TV',y = 'sales')
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = 'radio',y = 'sales')
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %%
sns.scatterplot(data = df, x = 'newspaper',y = 'sales')
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %%
sns.regplot(data = df , x = 'total',y= 'sales')
# Out:
# <AxesSubplot:xlabel='total', ylabel='sales'>

# %%
X = df['total']
y = df['sales']

# %%
np.polyfit(X,y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potensales = np.linspace(0,500,100)

# %%
predsales =  0.04868788*potensales + 4.24302822

# %%
sns.scatterplot(data = df , x = 'total', y = 'sales')
plt.plot(potensales,predsales, color = 'red')

# %%
spend = 200
predsales = 0.04868788*spend + 4.24302822
predsales
# Out:
# 13.98060422

# %%
np.polyfit(X,y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
predsales =3.07615033e-07*potensales**3 +-1.89392449e-04*potensales**2 + 8.20886302e-02*potensales +  2.70495053e+00

# %%
plt.plot(potensales,predsales)
sns.scatterplot(data = df , x = 'total', y = 'sales')
# Out:
# <AxesSubplot:xlabel='total', ylabel='sales'>

# %%
np.polyfit(X,y,9)
# Out:
# array([-9.68095219e-20,  1.93738552e-16, -1.64768910e-13,  7.75019631e-11,
#        -2.19692175e-08,  3.83301850e-06, -4.02581180e-04,  2.36231762e-02,
#        -5.95841334e-01,  8.90434236e+00])

# %%
predsales =  -9.68095219e-20*potensales**9 +  1.93738552e-16*potensales**8 + 1.64768910e-13*potensales**7 + 7.75019631e-11*potensales**6 + 2.19692175e-08*potensales**5 +  3.83301850e-06*potensales**4 + 4.02581180e-04*potensales**3+  2.36231762e-02*potensales**2 + 5.95841334e-01*potensales +  8.90434236e+00

# %%
plt.plot(potensales,predsales)
sns.scatterplot(data = df , x = 'total', y = 'sales')
# Out:
# <AxesSubplot:xlabel='total', ylabel='sales'>
